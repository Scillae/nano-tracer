# %%
import pickle
ns_tm = ns_tm=pickle.load(open('D:\\Streaming-tmp\\dna\\dna4\\data\\composed_traj\\4arms\\20C-0.5M-GPU\\4arms@(20C,0.5M).ns','rb'))
ns=ns_tm.time_capsule[50100000]
a0 = ns.arms[0]

# %%
bp1=a0.base_pairs[1]
b10=bp1[0]
b11=bp1[1]
import numpy as np

# %%
bs10=np.array(b10.position)+0.4*np.array(b10.backbone)
bs11=np.array(b11.position)+0.4*np.array(b11.backbone)

# %%
np.linalg.norm(bs11-bs10)
# Out:
# 0.41423328572852225

# %%
p10=np.array(b10.position)
p11=np.array(b11.position)

# %%
np.linalg.norm(p11-p10)
# Out:
# 1.1986101573927763
