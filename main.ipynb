# %%
import pickle
nstk_dict, stk_dict = pickle.load(open('D:\\Streaming-tmp\\dna\\dna4\\results\\4arms-jun_0\\pj\\pj_vtime-4arms@(20C,0.1M)-jun_0.stack','rb'))
print('done')
# Out:
# done

# %%
import pickle
ns_tm = pickle.load(open('D:\\Streaming-tmp\\dna\\dna4\\data\\composed_traj\\4arms\\20C-0.1M-GPU\\4arms@(20C,0.1M).ns','rb'))
ns = ns_tm.time_capsule[50100000]
a0 = ns.arms[0]

# %%
import pickle
with open('tmp\\tmp_prom_sel_dict_FWHM.tmp','rb') as f: # 68ptile
    FWHM = pickle.load(f)
print()

# %%
print(a0.strand_id_0)
print(a0.strand_id_1)
print('a1')
print(ns.arms[1].strand_id_0)
print(ns.arms[1].strand_id_1)
print('a2')
print(ns.arms[2].strand_id_0)
print(ns.arms[2].strand_id_1)
print('a3')
print(ns.arms[3].strand_id_0)
print(ns.arms[3].strand_id_1)
# Out:
# 1
# 4
# a1
# 4
# 3
# a2
# 3
# 2
# a3
# 2
# 1

# %%
bp1=a0.base_pairs[1]
b10=bp1[0]
b11=bp1[1]
import numpy as np

# %%
bs10=np.array(b10.position)+0.4*np.array(b10.backbone)
bs11=np.array(b11.position)+0.4*np.array(b11.backbone)

# %%
np.linalg.norm(bs11-bs10)
# Out:
# 0.41423328572852225

# %%
p10=np.array(b10.position)
p11=np.array(b11.position)

# %%
np.linalg.norm(p11-p10)
# Out:
# 1.1986101573927763
